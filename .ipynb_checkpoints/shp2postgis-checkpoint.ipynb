# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine
from geoalchemy2 import Geography, Geometry, WKTElement
from shapely.geometry.linestring import LineString
from shapely.geometry.multilinestring import MultiLineString
from geopandas_postgis import PostGIS

# %%
engine = create_engine("postgresql://USER:PASSWORD@HOST.COM.BR:PORT/DATABASE")

# %%
stations = gpd.read_file('shapefile/estacoes_telemetricas.shp', encoding='utf-8')

# %%
stations['geom'] = stations['geometry'].apply(lambda x: WKTElement(x.wkt, srid = 4326))

# %%
stations.drop('geometry', 1, inplace = True)

# %%
forecast = pd.read_csv('hidroforecast.csv', sep = ',')

# %%
stations
# Out:
#          code  drainarea           river    lat    lon  qsup    forecast  \
# 0  45880000.0     9550.0     RIO FORMOSO -13.56 -44.30  17.4   45.359905
# 1  45740001.0     7950.0     RIO DO MEIO -13.29 -44.56   9.0   19.187587
# 2  45960001.0    31000.0    RIO CORRENTE -13.29 -43.91  45.2  132.312141
# 3  45590000.0     3900.0  RIO CORRENTINA -13.34 -44.64   1.0   18.387299
# 4  45770000.0     5540.0    RIO ARROJADO -13.45 -44.57  14.4   63.710578
# 5  45840000.0     7130.0     RIO FORMOSO -13.71 -44.64  17.2   42.908450
# 6  46590000.0     7480.0      RIO BRANCO -11.86 -45.12  13.0   23.038945
# 7  46415000.0     4950.0      RIO GRANDE -12.43 -45.09  13.2   13.823081
# 8  46543000.0     5380.0    RIO DE ONDAS -12.14 -45.10   9.3   21.613897
# 9  46675000.0    39600.0      RIO GRANDE -11.61 -44.16  48.4  107.699126
#
#                             location                   geom
# 0  Rio Formoso em Colônia do Formoso   POINT (-44.3 -13.56)
# 1             Rio do Meio em Mocambo  POINT (-44.56 -13.29)
# 2         Rio Corrente em Porto Novo  POINT (-43.91 -13.29)
# 3       Rio Correntina em Correntina  POINT (-44.64 -13.34)
# 4           Rio Arrojado em Arrojado  POINT (-44.57 -13.45)
# 5               Rio Formoso em Gatos  POINT (-44.64 -13.71)
# 6   Rio Branco em Nova Vida Montante  POINT (-45.12 -11.86)
# 7         Rio Grande em Sítio Grande  POINT (-45.09 -12.43)
# 8  Rio de Ondas em Fazenda Rendenção   POINT (-45.1 -12.14)
# 9    Rio Grande em Fazenda Macambira  POINT (-44.16 -11.61)

# %%
forecast
# Out:
#    Unnamed: 0   Estacao                        Localizacao  Qsup  \
# 0           0  45590000       Rio Correntina em Correntina   1.0
# 1           1  45740001             Rio do Meio em Mocambo   9.0
# 2           2  45770000           Rio Arrojado em Arrojado  14.4
# 3           3  45840000               Rio Formoso em Gatos  17.2
# 4           4  45880000  Rio Formoso em Colônia do Formoso  17.4
# 5           5  45960001         Rio Corrente em Porto Novo  45.2
# 6           6  46415000         Rio Grande em Sítio Grande  13.2
# 7           7  46543000  Rio de Ondas em Fazenda Rendenção   9.3
# 8           8  46590000   Rio Branco em Nova Vida Montante  13.0
# 9           9  46675000    Rio Grande em Fazenda Macambira  48.4
#
#    VazaoMinPrev        Status isForecast
# 0     17.616532         Baixo        yes
# 1     13.524047         Baixo        yes
# 2           NaN  Sem previsão         no
# 3     26.872779         Baixo        yes
# 4     10.334306          Alto        yes
# 5     76.440208         Baixo        yes
# 6      8.490516          Alto        yes
# 7     21.044745         Baixo        yes
# 8     23.830654         Baixo        yes
# 9           NaN  Sem previsão         no

# %%
newstations = stations.sort_values("code", ascending = True)
newstations = newstations.reset_index(drop=True)

# %%
newforecast = forecast.sort_values("Estacao", ascending = True)
newforecast = newforecast.reset_index(drop=True)

# %%
newstations['qsup'] = newforecast['Qsup']
newstations['status'] = newforecast['Status']
newstations['isforecast'] = newforecast['isForecast']
newstations['forecast'] = newforecast['VazaoMinPrev']

# %%
newstations['code'] = newstations['code'].astype(int)

# %%
newstations = newstations.reset_index(drop=True)

# %%
dtype = {
    'code': sqlalchemy.types.Integer,
    'drainarea': sqlalchemy.types.Float,
    'river': sqlalchemy.types.String,
    'lat': sqlalchemy.types.Float,
    'lon': sqlalchemy.types.Float,
    'qsup': sqlalchemy.types.Float,
    'status': sqlalchemy.types.String,
    'forecast': sqlalchemy.types.Float,
    'isforecast': sqlalchemy.types.String,
    'geom':  Geometry('POINT', srid= 4326)
}

# %%
newstations
# Out:
#        code  drainarea           river    lat    lon  qsup   forecast  \
# 0  45590000     3900.0  RIO CORRENTINA -13.34 -44.64   1.0  17.630998
# 1  45740001     7950.0     RIO DO MEIO -13.29 -44.56   9.0  13.517248
# 2  45770000     5540.0    RIO ARROJADO -13.45 -44.57  14.4        NaN
# 3  45840000     7130.0     RIO FORMOSO -13.71 -44.64  17.2  26.778120
# 4  45880000     9550.0     RIO FORMOSO -13.56 -44.30  17.4  10.329310
# 5  45960001    31000.0    RIO CORRENTE -13.29 -43.91  45.2  76.365696
# 6  46415000     4950.0      RIO GRANDE -12.43 -45.09  13.2   8.296965
# 7  46543000     5380.0    RIO DE ONDAS -12.14 -45.10   9.3  20.659623
# 8  46590000     7480.0      RIO BRANCO -11.86 -45.12  13.0  23.512273
# 9  46675000    39600.0      RIO GRANDE -11.61 -44.16  48.4        NaN
#
#                             location                   geom        status  \
# 0       Rio Correntina em Correntina  POINT (-44.64 -13.34)         Baixo
# 1             Rio do Meio em Mocambo  POINT (-44.56 -13.29)         Baixo
# 2           Rio Arrojado em Arrojado  POINT (-44.57 -13.45)  Sem previsão
# 3               Rio Formoso em Gatos  POINT (-44.64 -13.71)         Baixo
# 4  Rio Formoso em Colônia do Formoso   POINT (-44.3 -13.56)          Alto
# 5         Rio Corrente em Porto Novo  POINT (-43.91 -13.29)         Baixo
# 6         Rio Grande em Sítio Grande  POINT (-45.09 -12.43)          Alto
# 7  Rio de Ondas em Fazenda Rendenção   POINT (-45.1 -12.14)         Baixo
# 8   Rio Branco em Nova Vida Montante  POINT (-45.12 -11.86)         Baixo
# 9    Rio Grande em Fazenda Macambira  POINT (-44.16 -11.61)  Sem previsão
#
#   isforecast
# 0        yes
# 1        yes
# 2         no
# 3        yes
# 4        yes
# 5        yes
# 6        yes
# 7        yes
# 8        yes
# 9         no

# %%
# newstations.to_sql(name = 'estacoes_telemetricas',
#                   con = engine, 
#                   schema = 'vector',
#                   if_exists='replace',
#                   dtype = dtype,
#                   index = False)

newstations.to_sql(name = 'estacoes_telemetricas', 
                               con = engine, 
                               if_exists = 'replace', 
                               schema = 'vector',
                               index = False, 
                               dtype=dtype)
